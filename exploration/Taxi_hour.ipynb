# %%
import numpy as np
from pandas import read_csv, cut, IntervalIndex

# %%
df = read_csv('train100K.csv', parse_dates=['pickup_datetime'], infer_datetime_format=True)
df['dayofweek'] = df['pickup_datetime'].dt.dayofweek.astype('uint8')
df['hour'] = df['pickup_datetime'].dt.hour.astype('uint8')
df['day'] = df['pickup_datetime'].dt.day.astype('uint8')
df['month'] = df['pickup_datetime'].dt.month.astype('uint8')
df['year'] = df['pickup_datetime'].dt.year.astype('uint16')
df['weekend'] = np.where(df.dayofweek < 5,0,1).astype('uint8')
df['period'] = np.where(df['pickup_datetime'] < '2012-09-01',0,1).astype('uint8')

# %%
df.head()
# Out:
#                              key  fare_amount     pickup_datetime  \
# 0    2015-05-11 11:42:51.0000003         10.5 2015-05-11 11:42:51
# 1   2013-10-20 13:27:00.00000065          7.5 2013-10-20 13:27:00
# 2  2012-08-04 22:25:00.000000114          4.5 2012-08-04 22:25:00
# 3    2011-10-22 23:12:35.0000003         14.5 2011-10-22 23:12:35
# 4    2013-11-06 12:44:10.0000001         13.0 2013-11-06 12:44:10
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.978989        40.761620         -73.963959         40.770561
# 1        -73.980350        40.763070         -73.988682         40.753977
# 2        -74.002282        40.726577         -74.009582         40.723597
# 3        -73.932800        40.758900         -73.995000         40.736600
# 4        -73.975421        40.761071         -73.998444         40.724890
#
#    passenger_count  dayofweek  hour  day  month  year  weekend  period
# ...

# %%
#bins = IntervalIndex.from_tuples([(0, 6),
#                                     (6, 12),
#                                     (12, 16),
#                                     (16,24)], closed='left')
#df['h_class'] = cut(df['hour'], bins, labels=False)
#bins
df['h_class'] = np.where((df['hour'] >= 0) & (df['hour'] <= 6),1,0)
df['h_class'] = np.where((df['hour'] >= 6) & (df['hour'] <= 12),2,df['h_class'])
df['h_class'] = np.where((df['hour'] >= 12) & (df['hour'] <= 16),3,df['h_class'])
df['h_class'] = np.where((df['hour'] >= 16) & (df['hour'] <= 20),4,df['h_class'])
df['h_class'] = np.where((df['hour'] >= 20) & (df['hour'] < 24),5,df['h_class'])

# %%
df.head(20)
# Out:
#                               key  fare_amount     pickup_datetime  \
# 0     2015-05-11 11:42:51.0000003        10.50 2015-05-11 11:42:51
# 1    2013-10-20 13:27:00.00000065         7.50 2013-10-20 13:27:00
# 2   2012-08-04 22:25:00.000000114         4.50 2012-08-04 22:25:00
# 3     2011-10-22 23:12:35.0000003        14.50 2011-10-22 23:12:35
# 4     2013-11-06 12:44:10.0000001        13.00 2013-11-06 12:44:10
# 5   2013-03-01 20:03:00.000000274         8.00 2013-03-01 20:03:00
# 6     2010-11-10 21:24:57.0000001         4.10 2010-11-10 21:24:57
# 7     2014-04-24 17:05:32.0000002        15.50 2014-04-24 17:05:32
# 8   2014-08-19 13:22:00.000000164         6.50 2014-08-19 13:22:00
# 9    2012-08-14 14:51:00.00000027         4.10 2012-08-14 14:51:00
# 10   2009-03-30 16:40:00.00000073        26.65 2009-03-30 16:40:00
# 11  2010-04-28 13:25:00.000000191         5.30 2010-04-28 13:25:00
# 12    2014-03-22 08:56:27.0000002         9.00 2014-03-22 08:56:27
# ...

# %%
# ?cut
